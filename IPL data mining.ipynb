# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cricket_data = pd.read_csv('cricket_matches.txt', sep="-")
cricket_data.columns=['H','H_Score','A', 'A_Score']

# %%
cricket_data
# Out:
#                                H  H_Score                              A  \
# 0              Rajasthan Royals       285               Kings XI Punjab
# 1               Kings XI Punjab       322                Mumbai Indians
# 2           Chennai Super Kings       281              Rajasthan Royals
# 3           Chennai Super Kings       337         Kolkata Knight Riders
# 4               Kings XI Punjab       339           Chennai Super Kings
# 5         Kolkata Knight Riders       315               Kings XI Punjab
# 6                Mumbai Indians       275           Chennai Super Kings
# 7   Royal Challengers Bangalore       331               Kings XI Punjab
# 8              Rajasthan Royals       332         Kolkata Knight Riders
# 9              Rajasthan Royals       340   Royal Challengers Bangalore
# 10               Mumbai Indians       331           Chennai Super Kings
# 11               Mumbai Indians       331           Sunrisers Hyderabad
# ...

# %%
cricket_data['H_Score'].mean()
# Out:
# 319.2686567164179

# %%
cricket_data['A_Score'].mean()
# Out:
# 323.64179104477614

# %%
cricket_data['A_Score'].plot(kind='bar')

# %%
cricket_data['H_Score'].plot(kind='bar')

# %%
cricket_data.sort_values(by='H')
# Out:
#                                H  H_Score                              A  \
# 2           Chennai Super Kings       281              Rajasthan Royals
# 3           Chennai Super Kings       337         Kolkata Knight Riders
# 21          Chennai Super Kings       330               Kings XI Punjab
# 32          Chennai Super Kings       349                Mumbai Indians
# 19          Chennai Super Kings       377                Mumbai Indians
# 65          Chennai Super Kings       310           Sunrisers Hyderabad
# 55          Chennai Super Kings       319           Chennai Super Kings
# 57          Chennai Super Kings       319           Sunrisers Hyderabad
# 63          Chennai Super Kings       288   Royal Challengers Bangalore
# 25          Chennai Super Kings       306   Royal Challengers Bangalore
# 26              Kings XI Punjab       322                Mumbai Indians
# 60              Kings XI Punjab       307         Kolkata Knight Riders
# ...
